# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price_df = pd.read_csv(
    "../datasets/products/medicine_price_dataset.csv"
)

product_df = pd.read_csv(
    "../datasets/products/pharma_products_dataset.csv"
)

# %%
price_df.head()
# Out:
#    medicine_id medicine_name   category      company  dosage_mg  pack_size  \
# 0            1          Napa  Injection       Renata        500          1
# 1            2           Ace     Tablet      Incepta        500          5
# 2            3   Paracetamol    Capsule  NovoNordisk        100          5
# 3            4           Ace     Tablet       Square        100          1
# 4            5           Ace      Syrup  NovoNordisk       1000         20
#
#    manufacturing_cost import_status demand_level  expiry_months  \
# 0              147.61         Local          Low             12
# 1              106.09         Local          Low             18
# 2               59.57         Local          Low             16
# 3              119.89         Local       Medium             33
# 4               92.61      Imported          Low             36
#
#    prescription_required   price
# 0                      1  199.33
# 1                      0  146.89
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   medicine_id            5000 non-null   int64
#  1   medicine_name          5000 non-null   object
#  2   category               5000 non-null   object
#  3   company                5000 non-null   object
#  4   dosage_mg              5000 non-null   int64
#  5   pack_size              5000 non-null   int64
#  6   manufacturing_cost     5000 non-null   float64
#  7   import_status          5000 non-null   object
#  8   demand_level           5000 non-null   object
#  9   expiry_months          5000 non-null   int64
#  10  prescription_required  5000 non-null   int64
#  11  price                  5000 non-null   float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 468.9+ KB

# %%
price_df.shape
# Out:
# (5000, 12)

# %%
product_df.head()
# Out:
#   product_id brand_name  generic_name     manufacturer dosage_form strength  \
# 0     P00001   HealPlus  Atorvastatin  Global Remedies       Syrup    250mg
# 1     P00002      Medix   Paracetamol       ABC Pharma       Syrup    100mg
# 2     P00003   HealPlus   Paracetamol  Global Remedies    Ointment    250mg
# 3     P00004      Medix   Paracetamol  Global Remedies      Tablet     50mg
# 4     P00005   LifeCare     Metformin     Medicare Ltd    Ointment     50mg
#
#    pack_size    price  discount_percent  final_price is_prescription_required  \
# 0         15  1788.16                20      1430.53                      Yes
# 1         10  1640.42                20      1312.34                      Yes
# 2         15  1016.76                20       813.41                       No
# 3         20  1323.78                 0      1323.78                      Yes
# 4         20   652.83                20       522.26                      Yes
#
# ...

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   product_id                   2000 non-null   object
#  1   brand_name                   2000 non-null   object
#  2   generic_name                 2000 non-null   object
#  3   manufacturer                 2000 non-null   object
#  4   dosage_form                  2000 non-null   object
#  5   strength                     2000 non-null   object
#  6   pack_size                    2000 non-null   int64
#  7   price                        2000 non-null   float64
#  8   discount_percent             2000 non-null   int64
#  9   final_price                  2000 non-null   float64
#  10  is_prescription_required     2000 non-null   object
#  11  drug_type                    2000 non-null   object
#  12  therapeutic_class            2000 non-null   object
# ...

# %%
product_df.shape
# Out:
# (2000, 20)

# %%
price_df.isnull().sum()
# Out:
# medicine_id              0
# medicine_name            0
# category                 0
# company                  0
# dosage_mg                0
# pack_size                0
# manufacturing_cost       0
# import_status            0
# demand_level             0
# expiry_months            0
# prescription_required    0
# price                    0
# dtype: int64

# %%
product_df.isnull().sum()
# Out:
# product_id                     0
# brand_name                     0
# generic_name                   0
# manufacturer                   0
# dosage_form                    0
# strength                       0
# pack_size                      0
# price                          0
# discount_percent               0
# final_price                    0
# is_prescription_required       0
# drug_type                      0
# therapeutic_class              0
# storage_condition              0
# shelf_life_months              0
# country                        0
# availability_status            0
# rating                         0
# num_reviews                    0
# contains_ai_generated_label    0
# dtype: int64

# %%
price_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
product_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
price_df.columns
# Out:
# Index(['medicine_id', 'medicine_name', 'category', 'company', 'dosage_mg',
#        'pack_size', 'manufacturing_cost', 'import_status', 'demand_level',
#        'expiry_months', 'prescription_required', 'price'],
#       dtype='object')

# %%
product_df.columns
# Out:
# Index(['product_id', 'brand_name', 'generic_name', 'manufacturer',
#        'dosage_form', 'strength', 'pack_size', 'price', 'discount_percent',
#        'final_price', 'is_prescription_required', 'drug_type',
#        'therapeutic_class', 'storage_condition', 'shelf_life_months',
#        'country', 'availability_status', 'rating', 'num_reviews',
#        'contains_ai_generated_label'],
#       dtype='object')

# %%
price_df.describe(include="all")
# Out:
#         medicine_id medicine_name category  company    dosage_mg    pack_size  \
# count   5000.000000          5000     5000     5000  5000.000000  5000.000000
# unique          NaN             7        4        5          NaN          NaN
# top             NaN   Paracetamol   Tablet  Beximco          NaN          NaN
# freq            NaN           767     1274     1051          NaN          NaN
# mean    2500.500000           NaN      NaN      NaN   378.550000     9.167400
# std     1443.520003           NaN      NaN      NaN   344.146894     7.079138
# min        1.000000           NaN      NaN      NaN    50.000000     1.000000
# 25%     1250.750000           NaN      NaN      NaN   100.000000     5.000000
# 50%     2500.500000           NaN      NaN      NaN   250.000000    10.000000
# 75%     3750.250000           NaN      NaN      NaN   500.000000    20.000000
# max     5000.000000           NaN      NaN      NaN  1000.000000    20.000000
#
# ...

# %%
price_df["category"].value_counts()
# Out:
# category
# Tablet       1274
# Capsule      1258
# Injection    1234
# Syrup        1234
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))

price_df["category"]\
.value_counts()\
.head(10)\
.plot(kind="bar")

plt.title("Medicine Categories")
plt.show()

# %%
plt.figure(figsize=(10,5))
price_df["company"]\
.value_counts()\
.head(10)\
.plot(kind="bar")

plt.title("Top Companies")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    price_df["price"],
    bins=20,
    kde=True
)

plt.title("Medicine Price Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(
    product_df["rating"],
    bins=20,
    kde=True
)
plt.title("Product Rating Distribution")
plt.show()

# %%
def search_medicine(name):
    result=price_df[
        price_df["medicine_name"].str.contains(
            name,
            case=False,
            na=False
        )
    ]

    return result

# %%
search_medicine("para")
# Out:
#       medicine_id medicine_name   category      company  dosage_mg  pack_size  \
# 2               3   Paracetamol    Capsule  NovoNordisk        100          5
# 26             27   Paracetamol  Injection      Incepta       1000          1
# 28             29   Paracetamol      Syrup      Incepta       1000          5
# 32             33   Paracetamol  Injection  NovoNordisk        100         20
# 41             42   Paracetamol      Syrup      Beximco       1000         20
# ...           ...           ...        ...          ...        ...        ...
# 4959         4960   Paracetamol      Syrup      Beximco        500          5
# 4968         4969   Paracetamol     Tablet  NovoNordisk         50         10
# 4971         4972   Paracetamol      Syrup  NovoNordisk        100         10
# 4989         4990   Paracetamol     Tablet  NovoNordisk       1000          5
# 4996         4997   Paracetamol     Tablet       Renata        500         10
#
# ...

# %%
price_df["demand_level"].value_counts()
# Out:
# demand_level
# Medium    1712
# Low       1654
# High      1634
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

price_df["demand_level"]\
.value_counts()\
.plot(kind="bar")

plt.title("Demand Level Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    price_df["expiry_months"],
    bins=20,
    kde=True
)
plt.title("Medicine Shelf Life Distribution")
plt.show()

# %%
product_df["rating"].describe()
# Out:
# count    2000.000000
# mean        3.752100
# std         0.719649
# min         2.500000
# 25%         3.100000
# 50%         3.800000
# 75%         4.400000
# max         5.000000
# Name: rating, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(
    product_df["rating"],
    bins=20,
    kde=True
)

plt.title("Product Rating Distribution")
plt.show()

# %%
top_products=(
    product_df
    .sort_values(
        by="rating",
        ascending=False
    )
)

top_products[
    [
    "brand_name",
    "manufacturer",
    "rating"
    ]
].head(10)
# Out:
#      brand_name     manufacturer  rating
# 689    LifeCare        Nova Life     5.0
# 1         Medix       ABC Pharma     5.0
# 1326   HealPlus     Medicare Ltd     5.0
# 18        Medix  Global Remedies     5.0
# 1068      Medix        Nova Life     5.0
# 566   PharmaOne       ABC Pharma     5.0
# 1944   BioTrust        Nova Life     5.0
# 664       Medix   Sun Healthcare     5.0
# 126    LifeCare   Sun Healthcare     5.0
# 272       Medix   Sun Healthcare     5.0

# %%
def search_medicine(name):
    result=price_df[
        price_df["medicine_name"].str.contains(
            name,
            case=False,
            na=False
        )
    ]

    return result

# %%
search_medicine("Para")
# Out:
#       medicine_id medicine_name   category      company  dosage_mg  pack_size  \
# 2               3   Paracetamol    Capsule  NovoNordisk        100          5
# 26             27   Paracetamol  Injection      Incepta       1000          1
# 28             29   Paracetamol      Syrup      Incepta       1000          5
# 32             33   Paracetamol  Injection  NovoNordisk        100         20
# 41             42   Paracetamol      Syrup      Beximco       1000         20
# ...           ...           ...        ...          ...        ...        ...
# 4959         4960   Paracetamol      Syrup      Beximco        500          5
# 4968         4969   Paracetamol     Tablet  NovoNordisk         50         10
# 4971         4972   Paracetamol      Syrup  NovoNordisk        100         10
# 4989         4990   Paracetamol     Tablet  NovoNordisk       1000          5
# 4996         4997   Paracetamol     Tablet       Renata        500         10
#
# ...

# %%
price_df["medicine_name"].head(20)
# Out:
# 0            Napa
# 1             Ace
# 2     Paracetamol
# 3             Ace
# 4             Ace
# 5           Seclo
# 6            Napa
# 7           Seclo
# 8          Ceevit
# 9          Ceevit
# 10           Napa
# 11           Napa
# 12          Seclo
# 13         Ceevit
# 14            Ace
# 15        Insulin
# 16        Insulin
# 17        Insulin
# 18          Seclo
# 19           Napa
# Name: medicine_name, dtype: object

# %%
def search_medicine(name):
    result=product_df[
        product_df["brand_name"].str.contains(
            name,
            case=False,
            na=False
        )
    ]
    return result
search_medicine("Crocin")
# Out:
# Empty DataFrame
# Columns: [product_id, brand_name, generic_name, manufacturer, dosage_form, strength, pack_size, price, discount_percent, final_price, is_prescription_required, drug_type, therapeutic_class, storage_condition, shelf_life_months, country, availability_status, rating, num_reviews, contains_ai_generated_label]
# Index: []

# %%
product_intelligence=product_df[
    [
        "brand_name",
        "generic_name",
        "manufacturer",
        "therapeutic_class",
        "price",
        "final_price",
        "availability_status",
        "rating",
        "num_reviews"
    ]
]

# %%
product_intelligence.head()
# Out:
#   brand_name  generic_name     manufacturer therapeutic_class    price  \
# 0   HealPlus  Atorvastatin  Global Remedies  Antihypertensive  1788.16
# 1      Medix   Paracetamol       ABC Pharma           Antacid  1640.42
# 2   HealPlus   Paracetamol  Global Remedies        Antibiotic  1016.76
# 3      Medix   Paracetamol  Global Remedies           Antacid  1323.78
# 4   LifeCare     Metformin     Medicare Ltd      Antidiabetic   652.83
#
#    final_price availability_status  rating  num_reviews
# 0      1430.53            In stock     2.6          274
# 1      1312.34        Out of stock     5.0           33
# 2       813.41            In stock     3.2          404
# 3      1323.78            In stock     2.7          116
# 4       522.26            In stock     3.2          471

# %%
import os
os.makedirs("../outputs",exist_ok=True)

# %%
product_intelligence.to_csv(
    "../outputs/product_intelligence.csv",
    index=False
)
